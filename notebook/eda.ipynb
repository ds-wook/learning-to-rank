# %%
import numpy as np
import pandas as pd

# %%
path = "../input/anime-recommendation/"
anime_info_df = pd.read_csv(path + "anime_info.csv")
relavence_scores = pd.read_csv(path + "relavence_scores.csv")
user_info = pd.read_csv(path + "user_info.csv")

# %%
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer


def create_genre_flags(df, popular_genres):
    df = df.dropna(subset=["Genres"])
    df["Genres"] = df["Genres"].apply(lambda x: ",".join(s.strip() for s in x.split(",")))
    # use MultiLabelBinarizer to create a one-hot encoded dataframe of the genres
    mlb = MultiLabelBinarizer()
    genre_df = pd.DataFrame(mlb.fit_transform(df["Genres"].str.split(",")), columns=mlb.classes_, index=df.index)
    # create a new dataframe with the movie id and genre columns
    new_df = pd.concat([df["anime_id"], genre_df[popular_genres]], axis=1)
    new_df.columns = ["anime_id"] + popular_genres
    return new_df


popular_genres = [
    "Comedy",
    "Action",
    "Fantasy",
    "Adventure",
    "Kids",
    "Drama",
    "Sci-Fi",
    "Music",
    "Shounen",
    "Slice of Life",
]

anime_genre_info_df = create_genre_flags(anime_info_df, popular_genres)
# Out:
# /tmp/ipykernel_136242/2911996815.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Genres"] = df["Genres"].apply(lambda x: ",".join(s.strip() for s in x.split(",")))

# %%
anime_info_df_final = anime_info_df.merge(anime_genre_info_df, on="anime_id")

# %%
train_interim = relavence_scores.merge(anime_info_df_final, on="anime_id")
train = train_interim.merge(user_info, how="inner")

# %%
train.head()
# Out:
#    anime_id                             Name  user_id  relavence_score  \
# 0         5  Cowboy Bebop: Tengoku no Tobira       60              0.0
# 1         5  Cowboy Bebop: Tengoku no Tobira      189              1.0
# 2         5  Cowboy Bebop: Tengoku no Tobira      191              1.0
# 3         5  Cowboy Bebop: Tengoku no Tobira      235              0.0
# 4         5  Cowboy Bebop: Tengoku no Tobira      240              0.0
#
#                                   Genres  is_tv  year_aired  is_adult  \
# 0  Action, Drama, Mystery, Sci-Fi, Space      0      2001.0         1
# 1  Action, Drama, Mystery, Sci-Fi, Space      0      2001.0         1
# 2  Action, Drama, Mystery, Sci-Fi, Space      0      2001.0         1
# 3  Action, Drama, Mystery, Sci-Fi, Space      0      2001.0         1
# 4  Action, Drama, Mystery, Sci-Fi, Space      0      2001.0         1
#
#    above_five_star_users  above_five_star_ratings  ...  Kids  Drama  Sci-Fi  \
# 0                    NaN                      NaN  ...     0      1       1
# 1                    NaN                      NaN  ...     0      1       1
# 2                    NaN                      NaN  ...     0      1       1
# 3                    NaN                      NaN  ...     0      1       1
# 4                    NaN                      NaN  ...     0      1       1
#
#    Music  Shounen  Slice of Life  review_count  avg_score  score_stddev  \
# 0      0        0              0          1704   0.000000      0.000000
# 1      0        0              0            77   0.493506      2.125183
# 2      0        0              0           278   0.000000      0.000000
# 3      0        0              0           667   0.290855      1.626348
# 4      0        0              0          2232   0.831093      2.089581
#
#    above_five_star_count
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 25 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998693 entries, 0 to 998692
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   anime_id                 998693 non-null  int64
#  1   Name                     998693 non-null  object
#  2   user_id                  998693 non-null  int64
#  3   relavence_score          998693 non-null  float64
#  4   Genres                   998693 non-null  object
#  5   is_tv                    998693 non-null  int64
#  6   year_aired               996935 non-null  float64
#  7   is_adult                 998693 non-null  int64
#  8   above_five_star_users    27 non-null      float64
#  9   above_five_star_ratings  27 non-null      float64
#  10  above_five_star_ratio    27 non-null      float64
#  11  Comedy                   998693 non-null  int64
#  12  Action                   998693 non-null  int64
#  13  Fantasy                  998693 non-null  int64
#  14  Adventure                998693 non-null  int64
#  15  Kids                     998693 non-null  int64
#  16  Drama                    998693 non-null  int64
#  17  Sci-Fi                   998693 non-null  int64
#  18  Music                    998693 non-null  int64
#  19  Shounen                  998693 non-null  int64
#  20  Slice of Life            998693 non-null  int64
#  21  review_count             998693 non-null  int64
#  22  avg_score                998693 non-null  float64
#  23  score_stddev             998674 non-null  float64
#  24  above_five_star_count    27 non-null      float64
# dtypes: float64(8), int64(15), object(2)
# memory usage: 190.5+ MB
